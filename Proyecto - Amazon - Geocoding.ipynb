# %% [markdown]
# # Sistema de Predicción y Visualización de Datos Delictivos en la Zona Metropolitana del Valle de México Mediante la Ingesta de Datos de la Red Social Twitter

# %% [markdown]
# 1. Cargado de librerias a utilizar.

# %%
from geopy.geocoders import Nominatim as loc
import pandas as pd
import boto3
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-27c5cb8c410a> in <cell line: 3>()
#       1 from geopy.geocoders import Nominatim as loc
#       2 import pandas as pd
# ----> 3 import boto3
#
# ModuleNotFoundError: No module named 'boto3'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Se caraga la API de amazon y la cuenta de gmail para el uso de la geocodificación.

# %%
geo = loc(user_agent = 'enzusa09@gmail.com')
comprehend=boto3.client(service_name='comprehend', region_name='us-west-2')

# %% [markdown]
# 2. Cargar los CSV que se van a manipurar, siendo estos los que han sido extraidos de Twitter.

# %%
"""a. Se cargan los archivos que son de Asaltos, estos siendo de manera trimestral durande los años 2021 y 2022"""
df = pd.read_csv("Asaltos 1er Trimestre 2021.csv",encoding="utf-8") 
df2 = pd.read_csv("Asaltos 2do Trimestre 2021.csv",encoding="utf-8")
df3 = pd.read_csv("Asaltos 3er Trimestre 2021.csv",encoding="utf-8") 
df4 = pd.read_csv("Asaltos 4to Trimestre 2021.csv",encoding="utf-8")
df5 = pd.read_csv("Asaltos 1er Trimestre 2022.csv",encoding="utf-8") 
df6 = pd.read_csv("Asaltos 2do Trimestre 2022.csv",encoding="utf-8")
df7 = pd.read_csv("Asaltos 3er Trimestre 2022.csv",encoding="utf-8") 
df8 = pd.read_csv("Asaltos 4to Trimestre 2022.csv",encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-0e8649413a86> in <cell line: 2>()
#       1 """a. Se cargan los archivos que son de Asaltos, estos siendo de manera trimestral durande los años 2021 y 2022"""
# ----> 2 df = pd.read_csv("Asaltos 1er Trimestre 2021.csv",encoding="utf-8")
#       3 df2 = pd.read_csv("Asaltos 2do Trimestre 2021.csv",encoding="utf-8")
#       4 df3 = pd.read_csv("Asaltos 3er Trimestre 2021.csv",encoding="utf-8")
#       5 df4 = pd.read_csv("Asaltos 4to Trimestre 2021.csv",encoding="utf-8")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ...

# %%
"""b. Se cargan los archivos que son de Extorsión, estos siendo de manera trimestral durande los años 2021 y 2022"""
ds = pd.read_csv("Extorsión 1er Trimestre 2021.csv",encoding="utf-8") 
ds2 = pd.read_csv("Extorsión 2do Trimestre 2021.csv",encoding="utf-8")
ds3 = pd.read_csv("Extorsión 3er Trimestre 2021.csv",encoding="utf-8") 
ds4 = pd.read_csv("Extorsión 4to Trimestre 2021.csv",encoding="utf-8")
ds5 = pd.read_csv("Extorsión 1er Trimestre 2022.csv",encoding="utf-8") 
ds6 = pd.read_csv("Extorsión 2do Trimestre 2022.csv",encoding="utf-8")
ds7 = pd.read_csv("Extorsión 3er Trimestre 2022.csv",encoding="utf-8") 
ds8 = pd.read_csv("Extorsión 4to Trimestre 2022.csv",encoding="utf-8")

# %% [markdown]
# ### Amazon Comprehend.

# %% [markdown]
# 3. Uso de Amazon Comprehend, esto pasando unicamaente el texto del tweet para procesarlo y sacar las coordenadas de este.

# %%
"""Asaltos"""
A = df['Embedded_text']
A2 = df2['Embedded_text']
A3 = df3['Embedded_text']
A4 = df4['Embedded_text']
A5 = df5['Embedded_text']
A6 = df6['Embedded_text']
A7 = df7['Embedded_text']
A8 = df8['Embedded_text']

# %%
"""Extorsíon"""
E = ds['Embedded_text']
E2 = ds2['Embedded_text']
E3 = ds3['Embedded_text']
E4 = ds4['Embedded_text']
E5 = ds5['Embedded_text']
E6 = ds6['Embedded_text']
E7 = ds7['Embedded_text']
E8 = ds8['Embedded_text']

# %% [markdown]
# 3.1 Se crean las cadenas en donde se guardaran los resultados de estos.

# %%
"""Codigo AsaltoTrimestre/#/Año"""
AT121 = []
AT221 = []
AT321 = []
AT421 = []
AT122 = []
AT222 = []
AT322 = []
AT422 = []

# %%
"""Codigo ExtorsionTrimestre/#/Año"""
ET121 = []
ET221 = []
ET321 = []
ET421 = []
ET122 = []
ET222 = []
ET322 = []
ET422 = []

# %% [markdown]
# 3.2 Utilizacion de dos bucles para diferenciar los tipos de CSV

# %%
"""Asaltos"""
for e in A:
    try:
        json1 = comprehend.detect_entities(Text=e, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                AT121.append([e,entidad['Text']])
    except:
        pass
for e in A2:
    try:
        json1 = comprehend.detect_entities(Text=e, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                AT221.append([e,entidad['Text']])
    except:
        pass
for e in A3:
    try:
        json1 = comprehend.detect_entities(Text=e, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                AT321.append([e,entidad['Text']])
    except:
        pass
for e in A4:
    try:    
        json1 = comprehend.detect_entities(Text=e, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                AT421.append([e,entidad['Text']])
    except:
        pass
for e in A5:
    try:
        json1 = comprehend.detect_entities(Text=e, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                AT122.append([e,entidad['Text']])
    except:
        pass
for e in A6:
    try:
        json1 = comprehend.detect_entities(Text=e, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                AT222.append([e,entidad['Text']])
    except:
        pass
for e in A7:
    try:
        json1 = comprehend.detect_entities(Text=e, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                AT322.append([e,entidad['Text']])
    except:
        pass
for e in A8:
    try:
        json1 = comprehend.detect_entities(Text=e, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                AT422.append([e,entidad['Text']])
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25940\839349906.py in <module>
# ----> 1 for tweet in tweets:
#       2     try:
#       3         json1 = comprehend.detect_entities(Text=tweet, LanguageCode='es')
#       4         for entidad in json1['Entities']:
#       5             if entidad['Type'] == 'LOCATION':
#
# NameError: name 'tweets' is not defined

# %%
"""Extorsion"""
for a in E:
    try:
        json1 = comprehend.detect_entities(Text=a, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                ET121.append([a,entidad['Text']])
    except:
        pass
for a in E2:
    try:
        json1 = comprehend.detect_entities(Text=a, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                ET221.append([a,entidad['Text']])
    except:
        pass
for a in E3:
    try:   
        json1 = comprehend.detect_entities(Text=a, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                ET321.append([a,entidad['Text']])
    except:
        pass
for a in E4:
    try:      
        json1 = comprehend.detect_entities(Text=a, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                ET421.append([a,entidad['Text']])
    except:
        pass
for a in E5:
    try:
        json1 = comprehend.detect_entities(Text=a, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                ET122.append([a,entidad['Text']])
    except:
        pass
for a in E6:
    try: 
        json1 = comprehend.detect_entities(Text=a, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                ET222.append([a,entidad['Text']])
    except:
        pass
for a in E7:
    try:
        json1 = comprehend.detect_entities(Text=a, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                ET322.append([a,entidad['Text']])
    except:
        pass
for a in E8:
    try:  
        json1 = comprehend.detect_entities(Text=a, LanguageCode='es')
        for entidad in json1['Entities']:
            if entidad['Type'] == 'LOCATION':
                ET422.append([a,entidad['Text']])
    except:
        pass

# %% [markdown]
# Nota:
# Una vez teniendo las entidades, se crea un csv con los datos nuevos, donde unicamente se tienen:
#  - Tweet de origen y
#  - Entidad extraida.
#
# 3.3 Guardado de los datos obtenidos en un archivo csv por trimestre.

# %%
"""Asaltos"""
AsaltoT121 = pd.DataFrame(AT121,columns=["Tweet","Locacion"])
AsaltoT121.to_csv("Entidades de Asalto 1er Trimestre 2021.csv",encoding="UTF-8")

AsaltoT221 = pd.DataFrame(AT221,columns=["Tweet","Locacion"])
AsaltoT221.to_csv("Entidades de Asalto 2do Trimestre 2021.csv",encoding="UTF-8")

AsaltoT321 = pd.DataFrame(AT321,columns=["Tweet","Locacion"])
AsaltoT321.to_csv("Entidades de Asalto 3er Trimestre 2021.csv",encoding="UTF-8")

AsaltoT421 = pd.DataFrame(AT421,columns=["Tweet","Locacion"])
AsaltoT421.to_csv("Entidades de Asalto 4to Trimestre 2021.csv",encoding="UTF-8")

AsaltoT122 = pd.DataFrame(AT122,columns=["Tweet","Locacion"])
AsaltoT122.to_csv("Entidades de Asalto 1er Trimestre 2022.csv",encoding="UTF-8")

AsaltoT222 = pd.DataFrame(AT222,columns=["Tweet","Locacion"])
AsaltoT222.to_csv("Entidades de Asalto 2do Trimestre 2022.csv",encoding="UTF-8")

AsaltoT322 = pd.DataFrame(AT322,columns=["Tweet","Locacion"])
AsaltoT322.to_csv("Entidades de Asalto 3er Trimestre 2022.csv",encoding="UTF-8")

AsaltoT422 = pd.DataFrame(AT422,columns=["Tweet","Locacion"])
AsaltoT422.to_csv("Entidades de Asalto 4to Trimestre 2022.csv",encoding="UTF-8")

# %%
"""Extorsion"""
ExtorsionT121 = pd.DataFrame(AT121,columns=["Tweet","Locacion"])
ExtorsionT121.to_csv("Entidades de Extorsion 1er Trimestre 2021.csv",encoding="UTF-8")

ExtorsionT221 = pd.DataFrame(AT221,columns=["Tweet","Locacion"])
ExtorsionT221.to_csv("Entidades de Extorsion 2do Trimestre 2021.csv",encoding="UTF-8")

ExtorsionT321 = pd.DataFrame(AT321,columns=["Tweet","Locacion"])
ExtorsionT321.to_csv("Entidades de Extorsion 3er Trimestre 2021.csv",encoding="UTF-8")

ExtorsionT421 = pd.DataFrame(AT421,columns=["Tweet","Locacion"])
ExtorsionT421.to_csv("Entidades de Extorsion 4to Trimestre 2021.csv",encoding="UTF-8")

ExtorsionT122 = pd.DataFrame(AT122,columns=["Tweet","Locacion"])
ExtorsionT122.to_csv("Entidades de Extorsion 1er Trimestre 2022.csv",encoding="UTF-8")

ExtorsionT222 = pd.DataFrame(AT222,columns=["Tweet","Locacion"])
ExtorsionT222.to_csv("Entidades de Extorsion 2do Trimestre 2022.csv",encoding="UTF-8")

ExtorsionT322 = pd.DataFrame(AT322,columns=["Tweet","Locacion"])
ExtorsionT322.to_csv("Entidades de Extorsion 3er Trimestre 2022.csv",encoding="UTF-8")

ExtorsionT422 = pd.DataFrame(AT422,columns=["Tweet","Locacion"])
ExtorsionT422.to_csv("Entidades de Extorsion 4to Trimestre 2022.csv",encoding="UTF-8")

# %% [markdown]
# ### Obtención de Direcciones.

# %% [markdown]
# 4. Direcciones Completas.
# Una vez teniendo las Entidades, se puede pasar a obtener la direccion completa de la entidad, esto, filtrando los resultados para obtener unicamente los que sean de la Ciudad de México.
#
# 4.1 Se vuelven a cargar los CSV de los nuevos datos, para de esta manera tener una mejor manipulacion.

# %%
"""a. Se cargan los archivos que son de Asaltos ya pasados por un primer filtro,
   estos siendo de manera trimestral durande los años 2021 y 2022"""
df = pd.read_csv("Entidades de Asaltos 1er Trimestre 2021.csv",encoding="utf-8") 
df2 = pd.read_csv("Entidades de Asaltos 2do Trimestre 2021.csv",encoding="utf-8")
df3 = pd.read_csv("Entidades de Asaltos 3er Trimestre 2021.csv",encoding="utf-8") 
df4 = pd.read_csv("Entidades de Asaltos 4to Trimestre 2021.csv",encoding="utf-8")
df5 = pd.read_csv("Entidades de Asaltos 1er Trimestre 2022.csv",encoding="utf-8") 
df6 = pd.read_csv("Entidades de Asaltos 2do Trimestre 2022.csv",encoding="utf-8")
df7 = pd.read_csv("Entidades de Asaltos 3er Trimestre 2022.csv",encoding="utf-8") 
df8 = pd.read_csv("Entidades de Asaltos 4to Trimestre 2022.csv",encoding="utf-8")

# %%
"""b. Se cargan los archivos que son de Extorsion ya pasados por un primer filtro,
   estos siendo de manera trimestral durande los años 2021 y 2022"""
ds = pd.read_csv("Entidades de Extorsion 1er Trimestre 2021.csv",encoding="utf-8") 
ds2 = pd.read_csv("Entidades de Extorsion 2do Trimestre 2021.csv",encoding="utf-8")
ds3 = pd.read_csv("Entidades de Extorsion 3er Trimestre 2021.csv",encoding="utf-8") 
ds4 = pd.read_csv("Entidades de Extorsion 4to Trimestre 2021.csv",encoding="utf-8")
ds5 = pd.read_csv("Entidades de Extorsion 1er Trimestre 2022.csv",encoding="utf-8") 
ds6 = pd.read_csv("Entidades de Extorsion 2do Trimestre 2022.csv",encoding="utf-8")
ds7 = pd.read_csv("Entidades de Extorsion 3er Trimestre 2022.csv",encoding="utf-8") 
ds8 = pd.read_csv("Entidades de Extorsion 4to Trimestre 2022.csv",encoding="utf-8")

# %% [markdown]
# 4.2 Se cargan los datos a variables que unicamente contendran la locación.

# %%
"""Asaltos"""
A = df['Locacion']
A2 = df2['Locacion']
A3 = df3['Locacion']
A4 = df4['Locacion']
A5 = df5['Locacion']
A6 = df6['Locacion']
A7 = df7['Locacion']
A8 = df8['Locacion']

# %%
"""Extorsion"""
E = ds['Locacion']
E2 = ds2['Locacion']
E3 = ds3['Locacion']
E4 = ds4['Locacion']
E5 = ds5['Locacion']
E6 = ds6['Locacion']
E7 = ds7['Locacion']
E8 = ds8['Locacion']

# %% [markdown]
# 4.3 Una vez cargados, se procede a iniciar la obtencion de Direcciones y filtrarlas, a que estas pertenezcan a la Ciudad de México.

# %%
"""Datos de Asaltos"""
"""Se hace uso de 8 variables nuevas, esto para poder guardar las direcciones que se nos proporcionen 
   y posteriormente guardarlo en una nueva version del CSV para poder manipularlo mas adelante"""
coordenadasA = []
coordenadasA2 = []
coordenadasA3 = []
coordenadasA4 = []
coordenadasA5 = []
coordenadasA6 = []
coordenadasA7 = []
coordenadasA8 = []
"""La z es para hacer que la direccion que se guarte tenga el valor de un 1, 
   y posteiormente se pueda realizar una sumatoria de direcciones iguales"""
z=1
for e in A:
    try:
        location = geo.geocode(e)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasA.append([direccion,z])
    except:
        pass
for e in A2:
    try:
        location = geo.geocode(e)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasA2.append([direccion,z])
    except:
        pass
for e in A3:
    try:
        location = geo.geocode(e)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasA3.append([direccion,z])
    except:
        pass
for e in A4:
    try:
        location = geo.geocode(e)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasA4.append([direccion,z])
    except:
        pass
for e in A5:
    try:
        location = geo.geocode(e)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasA5.append([direccion,z])
    except:
        pass
for e in A6:
    try:
        location = geo.geocode(e)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasA6.append([direccion,z])
    except:
        pass
for e in A7:
    try:
        location = geo.geocode(e)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasA7.append([direccion,z])
    except:
        pass
for e in A8:
    try:
        location = geo.geocode(e)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasA8.append([direccion,z])
    except:
        pass

# %%
"""Datos de Extorsion"""
"""Se hace uso de 8 variables nuevas, esto para poder guardar las direcciones que se nos proporcionen 
   y posteriormente guardarlo en una nueva version del CSV para poder manipularlo mas adelante"""
coordenadasE = []
coordenadasE2 = []
coordenadasE3 = []
coordenadasE4 = []
coordenadasE5 = []
coordenadasE6 = []
coordenadasE7 = []
coordenadasE8 = []
"""La z es para hacer que la direccion que se guarte tenga el valor de un 1, 
   y posteiormente se pueda realizar una sumatoria de direcciones iguales"""
z=1
for a in E:
    try:
        location = geo.geocode(a)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasE.append([direccion,z])
    except:
        pass
for a in E2:
    try:
        location = geo.geocode(a)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasE2.append([direccion,z])
    except:
        pass
for a in E3:
    try:
        location = geo.geocode(a)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasE3.append([direccion,z])
    except:
        pass
for a in E4:
    try:
        location = geo.geocode(a)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasE4.append([direccion,z])
    except:
        pass
for a in E5:
    try:
        location = geo.geocode(a)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasE5.append([direccion,z])
    except:
        pass
for a in E6:
    try:
        location = geo.geocode(a)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasE6.append([direccion,z])
    except:
        pass
for a in E7:
    try:
        location = geo.geocode(a)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasE7.append([direccion,z])
    except:
        pass
for a in E8:
    try:
        location = geo.geocode(a)
        direccion = location.address
        if 'Ciudad de México' in direccion:
            coordenadasE8.append([direccion,z])
    except:
        pass

# %% [markdown]
# 4.4 Una vez teniendo los datos, son sumados y posteriormente guardados.

# %%
"""Asaltos"""
AsaltoT121 = pd.DataFrame(coordenadasA,columns=["Direccion","Cantidad"])
Datos = AsaltoT121.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Asalto 1er Trimestre 2021.csv",encoding="UTF-8")

AsaltoT221 = pd.DataFrame(coordenadasA2,columns=["Direccion","Cantidad"])
Datos = AsaltoT221.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Asalto 2do Trimestre 2021.csv",encoding="UTF-8")

AsaltoT321 = pd.DataFrame(coordenadasA3,columns=["Direccion","Cantidad"])
Datos = AsaltoT321.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Asalto 3er Trimestre 2021.csv",encoding="UTF-8")

AsaltoT421 = pd.DataFrame(coordenadasA4,columns=["Direccion","Cantidad"])
Datos = AsaltoT421.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Asalto 4to Trimestre 2021.csv",encoding="UTF-8")

AsaltoT122 = pd.DataFrame(coordenadasA5,columns=["Direccion","Cantidad"])
Datos = AsaltoT122.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Asalto 1er Trimestre 2022.csv",encoding="UTF-8")

AsaltoT222 = pd.DataFrame(coordenadasA6,columns=["Direccion","Cantidad"])
Datos = AsaltoT222.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Asalto 2do Trimestre 2022.csv",encoding="UTF-8")

AsaltoT322 = pd.DataFrame(coordenadasA7,columns=["Direccion","Cantidad"])
Datos = AsaltoT322.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Asalto 3er Trimestre 2022.csv",encoding="UTF-8")

AsaltoT422 = pd.DataFrame(coordenadasA8,columns=["Direccion","Cantidad"])
Datos = AsaltoT422.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Asalto 4to Trimestre 2022.csv",encoding="UTF-8")

# %%
"""Extorsión"""
ExtorsionT121 = pd.DataFrame(coordenadasE,columns=["Direccion","Cantidad"])
Datos =ExtorsionT121.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Extorsion 1er Trimestre 2021.csv",encoding="UTF-8")

ExtorsionT221 = pd.DataFrame(coordenadasE2,columns=["Direccion","Cantidad"])
Datos = ExtorsionT221.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Extorsion 2do Trimestre 2021.csv",encoding="UTF-8")

ExtorsionT321 = pd.DataFrame(coordenadasE3,columns=["Direccion","Cantidad"])
Datos = ExtorsionT321.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Extorsion 3er Trimestre 2021.csv",encoding="UTF-8")

ExtorsionT421 = pd.DataFrame(coordenadasE4,columns=["Direccion","Cantidad"])
Datos = ExtorsionT421.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Extorsion 4to Trimestre 2021.csv",encoding="UTF-8")

ExtorsionT122 = pd.DataFrame(coordenadasE5,columns=["Direccion","Cantidad"])
Datos = ExtorsionT122.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Extorsion 1er Trimestre 2022.csv",encoding="UTF-8")

ExtorsionT222 = pd.DataFrame(coordenadasE6,columns=["Direccion","Cantidad"])
Datos = ExtorsionT222.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Extorsion 2do Trimestre 2022.csv",encoding="UTF-8")

ExtorsionT322 = pd.DataFrame(coordenadasE7,columns=["Direccion","Cantidad"])
Datos = ExtorsionT322.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Extorsion 3er Trimestre 2022.csv",encoding="UTF-8")

ExtorsionT422 = pd.DataFrame(coordenadasE8,columns=["Direccion","Cantidad"])
Datos = ExtorsionT422.groupby("Direccion").sum()
Datos.to_csv("Conjunto de Direcciones de Extorsion 4to Trimestre 2022.csv",encoding="UTF-8")

# %% [markdown]
# Nota.
# Si se quisiese hacer un estudio por 6 meses o anual, se puede ocupar la siguiente funcion y juntar los csv para llegar al periodo requerido.
# glob.glob('Direccion de los archivos/*.csv') -> df = pd.concat(map(pd.read_csv, glob.glob('dir/*.csv')))

# %% [markdown]
# ### GeoCodificación

# %% [markdown]
# 5. Ya que se tiene el conjunto de datos, mas compacto y especifico, se puede sacar las cordenadas de los conjuntos trimestrales.
#
# 5.1 Volviendo a cargar las nuevas versiones de los archivos CSV

# %%
"""Asaltos"""
df = pd.read_csv("Conjunto de Direcciones de Asaltos 1er Trimestre 2021.csv",encoding="utf-8") 
df2 = pd.read_csv("Conjunto de Direcciones de Asaltos 2do Trimestre 2021.csv",encoding="utf-8")
df3 = pd.read_csv("Conjunto de Direcciones de Asaltos 3er Trimestre 2021.csv",encoding="utf-8") 
df4 = pd.read_csv("Conjunto de Direcciones de Asaltos 4to Trimestre 2021.csv",encoding="utf-8")
df5 = pd.read_csv("Conjunto de Direcciones de Asaltos 1er Trimestre 2022.csv",encoding="utf-8") 
df6 = pd.read_csv("Conjunto de Direcciones de Asaltos 2do Trimestre 2022.csv",encoding="utf-8")
df7 = pd.read_csv("Conjunto de Direcciones de Asaltos 3er Trimestre 2022.csv",encoding="utf-8") 
df8 = pd.read_csv("Conjunto de Direcciones de Asaltos 4to Trimestre 2022.csv",encoding="utf-8")

# %%
"""Extorsión"""
ds = pd.read_csv("Conjunto de Direcciones de Extorsion 1er Trimestre 2021.csv",encoding="utf-8") 
ds2 = pd.read_csv("Conjunto de Direcciones de Extorsion 2do Trimestre 2021.csv",encoding="utf-8")
ds3 = pd.read_csv("Conjunto de Direcciones de Extorsion 3er Trimestre 2021.csv",encoding="utf-8") 
ds4 = pd.read_csv("Conjunto de Direcciones de Extorsion 4to Trimestre 2021.csv",encoding="utf-8")
ds5 = pd.read_csv("Conjunto de Direcciones de Extorsion 1er Trimestre 2022.csv",encoding="utf-8") 
ds6 = pd.read_csv("Conjunto de Direcciones de Extorsion 2do Trimestre 2022.csv",encoding="utf-8")
ds7 = pd.read_csv("Conjunto de Direcciones de Extorsion 3er Trimestre 2022.csv",encoding="utf-8") 
ds8 = pd.read_csv("Conjunto de Direcciones de Extorsion 4to Trimestre 2022.csv",encoding="utf-8")

# %% [markdown]
# 4.6 Una vez cargados los datos, se le asignaran las a columnas a dos variables para poder hacer un CSV completo, la version final.

# %%
"""Asaltos"""
A = df['Direccion']
A2 = df2['Direccion']
A3 = df3['Direccion']
A4 = df4['Direccion']
A5 = df5['Direccion']
A6 = df6['Direccion']
A7 = df7['Direccion']
A8 = df8['Direccion']

SA = df['Cantidad']
SA2 = df2['Cantidad']
SA3 = df3['Cantidad']
SA4 = df4['Cantidad']
SA5 = df5['Cantidad']
SA6 = df6['Cantidad']
SA7 = df7['Cantidad']
SA8 = df8['Cantidad']

# %%
"""Extorsion"""
E = ds['Direccion']
E2 = ds2['Direccion']
E3 = ds3['Direccion']
E4 = ds4['Direccion']
E5 = ds5['Direccion']
E6 = ds6['Direccion']
E7 = ds7['Direccion']
E8 = ds8['Direccion']

SE = ds['Cantidad']
SE2 = ds2['Cantidad']
SE3 = ds3['Cantidad']
SE4 = ds4['Cantidad']
SE5 = ds5['Cantidad']
SE6 = ds6['Cantidad']
SE7 = ds7['Cantidad']
SE8 = ds8['Cantidad']

# %% [markdown]
# 5.2 Ya que se tienen los datos en Direcciones, y sus veces que se repite, permite la realizacion de la geocodificacion mas rapida, debido a que no se tiene que estar procesando el mismo dato, multiples veces.

# %%
"""Asaltos"""

coordenadasA = []
coordenadasA2 = []
coordenadasA3 = []
coordenadasA4 = []
coordenadasA5 = []
coordenadasA6 = []
coordenadasA7 = []
coordenadasA8 = []

for a, b in zip(A,SA):
    location = geo.geocode(a)
    coordenadasA.append([a,location.longitude,location.latitude,b])
for a, b in zip(A2,SA2):
    location = geo.geocode(a)
    coordenadasA2.append([a,location.longitude,location.latitude,b])
for a, b in zip(A3,SA3):
    location = geo.geocode(a)
    coordenadasA3.append([a,location.longitude,location.latitude,b])
for a, b in zip(A4,SA4):
    location = geo.geocode(a)
    coordenadasA4.append([a,location.longitude,location.latitude,b])
for a, b in zip(A5,SA5):
    location = geo.geocode(a)
    coordenadasA5.append([a,location.longitude,location.latitude,b])
for a, b in zip(A6,SA6):
    location = geo.geocode(a)
    coordenadasA6.append([a,location.longitude,location.latitude,b])
for a, b in zip(A7,SA7):
    location = geo.geocode(a)
    coordenadasA7.append([a,location.longitude,location.latitude,b])
for a, b in zip(A8,SA8):
    location = geo.geocode(a)
    coordenadasA8.append([a,location.longitude,location.latitude,b])

# %%
"""Extorsion"""

coordenadasE = []
coordenadasE2 = []
coordenadasE3 = []
coordenadasE4 = []
coordenadasE5 = []
coordenadasE6 = []
coordenadasE7 = []
coordenadasE8 = []

for a,b in zip(E,SE):
    location = geo.geocode(a)
    coordenadasE.append([a,location.longitude,location.latitude,b])
for a,b in zip(E2,SE2):
    location = geo.geocode(a)
    coordenadasE2.append([a,location.longitude,location.latitude,b])
for a,b in zip(E3,SE3):
    location = geo.geocode(a)
    coordenadasE3.append([a,location.longitude,location.latitude,b])
for a,b in zip(E4,SE4):
    location = geo.geocode(a)
    coordenadasE4.append([a,location.longitude,location.latitude,b])
for a,b in zip(E5,SE5):
    location = geo.geocode(a)
    coordenadasE5.append([a,location.longitude,location.latitude,b])
for a,b in zip(E6,SE6):
    location = geo.geocode(a)
    coordenadasE6.append([a,location.longitude,location.latitude,b])
for a,b in zip(E7,SE7):
    location = geo.geocode(a)
    coordenadasE7.append([a,location.longitude,location.latitude,b])
for a,b in zip(E8,SE8):
    location = geo.geocode(a)
    coordenadasE8.append([a,location.longitude,location.latitude,b])

# %% [markdown]
# 5.3 Una vez teniendo todas las coordenadas, se obtienen los datos filtrados y limpios.

# %%
"""Asaltos"""
AsaltoT121 = pd.DataFrame(coordenadasA,columns=["Direccion","Longitud","Latitud","Cantidad"])
AsaltoT121.to_csv("Coordenadas de Asalto 1er Trimestre 2021.csv",encoding="UTF-8")

AsaltoT221 = pd.DataFrame(coordenadasA2,columns=["Direccion","Longitud","Latitud","Cantidad"])
AsaltoT221.to_csv("Coordenadas de Asalto 2do Trimestre 2021.csv",encoding="UTF-8")

AsaltoT321 = pd.DataFrame(coordenadasA3,columns=["Direccion","Longitud","Latitud","Cantidad"])
AsaltoT321.to_csv("Coordenadas de Asalto 3er Trimestre 2021.csv",encoding="UTF-8")

AsaltoT421 = pd.DataFrame(coordenadasA4,columns=["Direccion","Longitud","Latitud","Cantidad"])
AsaltoT421.to_csv("Coordenadas de Asalto 4to Trimestre 2021.csv",encoding="UTF-8")

AsaltoT122 = pd.DataFrame(coordenadasA5,columns=["Direccion","Longitud","Latitud","Cantidad"])
AsaltoT122.to_csv("Coordenadas de Asalto 1er Trimestre 2022.csv",encoding="UTF-8")

AsaltoT222 = pd.DataFrame(coordenadasA6,columns=["Direccion","Longitud","Latitud","Cantidad"])
AsaltoT222.to_csv("Coordenadas de Asalto 2do Trimestre 2022.csv",encoding="UTF-8")

AsaltoT322 = pd.DataFrame(coordenadasA7,columns=["Direccion","Longitud","Latitud","Cantidad"])
AsaltoT322.to_csv("Coordenadas de Asalto 3er Trimestre 2022.csv",encoding="UTF-8")

AsaltoT422 = pd.DataFrame(coordenadasA8,columns=["Direccion","Longitud","Latitud","Cantidad"])
AsaltoT422.to_csv("Coordenadas de Asalto 4to Trimestre 2022.csv",encoding="UTF-8")

# %%
"""Extorsión"""
ExtorsionT121 = pd.DataFrame(coordenadasE,columns=["Direccion","Longitud","Latitud","Cantidad"])
Extorsion.to_csv("Coordenadas de Extorsion 1er Trimestre 2021.csv",encoding="UTF-8")

ExtorsionT221 = pd.DataFrame(coordenadasE2,columns=["Direccion","Longitud","Latitud","Cantidad"])
ExtorsionT221.to_csv("Coordenadas de Extorsion 2do Trimestre 2021.csv",encoding="UTF-8")

ExtorsionT321 = pd.DataFrame(coordenadasE3,columns=["Direccion","Longitud","Latitud","Cantidad"])
ExtorsionT321.to_csv("Coordenadas de Extorsion 3er Trimestre 2021.csv",encoding="UTF-8")

ExtorsionT421 = pd.DataFrame(coordenadasE4,columns=["Direccion","Longitud","Latitud","Cantidad"])
ExtorsionT421.to_csv("Coordenadas de Extorsion 4to Trimestre 2021.csv",encoding="UTF-8")

ExtorsionT122 = pd.DataFrame(coordenadasE5,columns=["Direccion","Longitud","Latitud","Cantidad"])
ExtorsionT122.to_csv("Coordenadas de Extorsion 1er Trimestre 2022.csv",encoding="UTF-8")

ExtorsionT222 = pd.DataFrame(coordenadasE6,columns=["Direccion","Longitud","Latitud","Cantidad"])
ExtorsionT222.to_csv("Coordenadas de Extorsion 2do Trimestre 2022.csv",encoding="UTF-8")

ExtorsionT322 = pd.DataFrame(coordenadasE7,columns=["Direccion","Longitud","Latitud","Cantidad"])
ExtorsionT322.to_csv("Coordenadas de Extorsion 3er Trimestre 2022.csv",encoding="UTF-8")

ExtorsionT422 = pd.DataFrame(coordenadasE8,columns=["Direccion","Longitud","Latitud","Cantidad"])
ExtorsionT422.to_csv("Coordenadas de Extorsion 4to Trimestre 2022.csv",encoding="UTF-8")

# %% [markdown]
# ### Densidad de Kernel

# %% [markdown]
# 6.1 Una vez con los datos limpios e spodible iniciar con el desarrollo de los mapas de calor.
